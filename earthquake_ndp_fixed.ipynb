# %% [markdown]
# ## Earthquakes and GNSS Data in NDP
# #### A Notebook in Natural Language

# %%
# %deepndp what skills do you have
# Out:
# I have access to the following skills:
#
# **Built-in Skills:**
# - **skill-creator** - Guide for creating effective skills that extend agent capabilities with specialized knowledge, workflows, or tool integrations
#
# **Custom Skills:**
# - **ndp-search** - Search the National Data Platform catalog using a proxy API with keyword, spatial, and temporal filters
# - **ndp-workspaces** - Load and manage workspace data from the NDP Workspace API using direct HTTP calls
# - **us-counties** - Get geometry definitions of USA counties as a geodataframe
# - **us-states** - Get geometry definitions of USA states as a geodataframe
# - **usgs-earthquake-events** - Retrieve earthquake events from USGS API and convert to GeoDataFrame for spatial analysis
#
# Each skill follows a progressive disclosure pattern - I can read the full instructions from their SKILL.md files when needed. Would you like me to use any of these skills for a specific task?

# %%
# %%deepndp
# Find earthquake events with magnitude > 5 in the United States between 2024-12-03 and 2024-12-15.
# Summarize the results and save them as a GeoJSON file.
# Out:
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/usgs-earthquake-events/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/usgs-earthquake-events/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>mkdir -p /tmp/deepndp/019d1e2d-ae6c-73d3-ba61-551419caebd2</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
# ...

# %%
# %%deepndp
# Identify GPS station datasets located within 100 miles of this earthquake event,
# and report the distance between each GPS station and the corresponding earthquake.
# Please use the skill ndp-search
# Out:
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ndp-search/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ndp-search/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0; font-size:0.85em;">
#   📋 <b>write_todos</b> — 5 todo(s)
#   <details open>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
# ...

# %%
# %%deepndp
# Download the dataset P127.PW.LY_.00 into a local folder, preserving the original file names.
# Out:
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ndp-workspaces/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ndp-workspaces/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/tmp/deepndp/019d1e2d-ae6c-73d3-ba61-551419caebd2/gps_stations.json</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
# ...

# %%
# %%deepndp
# analyze the raw data and pay special attention to the data around the time of the earthquake event
# Out:
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/tmp/deepndp/019d1e2d-ae6c-73d3-ba61-551419caebd2/P127.PW.LY_.00/P127.PW.LY_.00.csv</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/tmp/deepndp/019d1e2d-ae6c-73d3-ba61-551419caebd2/P127.PW.LY_.00/P127.PW.LY_.00.csv",
#   "limit": 50
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>wc -l /tmp/deepndp/019d1e2d-ae6c-73d3-ba61-551419caebd2/P127.PW.LY_.00/P127.P...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
# ...
