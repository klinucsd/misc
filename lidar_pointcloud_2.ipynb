# %% [markdown]
# # USGS 3DEP LiDAR Explorer
# Explore high-resolution airborne LiDAR point clouds collected by the U.S. Geological Survey's 3D Elevation Program (3DEP). Each LiDAR dataset captures the height of the ground, vegetation, and structures over a region by recording millions to billions of laser returns from aircraft. This notebook lets you pick a region of interest, download the point cloud, and turn it into a 1-meter digital elevation model (DEM) with hillshade.
#
# The workflow runs in five steps:
#
# 1. **Pick an area** — draw a rectangle on the USGS 3DEP coverage map and select a dataset that intersects it from the auto-populated dropdown
# 2. **Download the point cloud** — fetch the LiDAR returns for the selected area from the public Entwine Point Tile (EPT) service
# 3. **Inspect the point cloud** — point count, elevation range, classification breakdown, and a 3D preview colored by elevation
# 4. **Generate a DEM and hillshade** — rasterize the ground returns into a 1-meter DEM, then build a shaded relief view
# 5. **Visualize** — overlay the locally-computed hillshade against the USGS 3DEP WMS service for wider context
#
# Linked widgets in step 1 are powered by the `sage-bbox-map` and `sage-dropdown` UI skills, which subscribe to changes in kernel variables (`USER_BBOX` triggers the dataset filter automatically when you draw a rectangle). The `usgs-lidar` data skill provides only the data primitives — `fetch_coverage()` and `filter_by_bbox()` — and knows nothing about the UI.
#
# No coding needed — just run each cell and follow the prompts.

# %%
# %reset

# %%
# %%ask
# Create a USGS 3DEP coverage map with a bounding box selection tool.
# Show a dropdown of USGS 3DEP datasets that intersect the bounding box
# with under 20 million points.
# Out:
# I'll create a USGS 3DEP coverage map with a bounding box selection tool and a reactive dropdown. Let me first check the relevant skills to understand the available tools.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/py3dep-dem/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/py3dep-dem/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/sage-bbox-map/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/sage-bbox-map/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/sage-dropdown/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/sage-dropdown/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/usgs-lidar/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/usgs-lidar/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll create a script that combines the usgs-lidar data skill with the sage-bbox-map and sage-dropdown UI skills to create the interactive coverage map.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_lidar_pointcloud_sage_/usgs_3dep_coverage_map.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_lidar_pointcloud_sage_/usgs_3dep_coverage_map.py",
#   "content": "#!/usr/bin/env python\n\"\"\"\nUSGS 3DEP Coverage Map with Bounding Box Selection and Dataset Dropdown\nCombines usgs-lidar data skill with sage-bbox-map and sage-dropdown UI skills\n\"\"\"\n\nimport sys\n\n# Add skill directories to path\nsys.path.insert(0, \"/home/jovyan/.deepagents/agent/skills/usgs-lidar\")\nsys.path.insert(0, \"/home/jovyan/.deepagents/agent/skills/sage-bbox-map\")\nsys.path.insert(0, \"/home/jovyan/.deepagents/agent/skills/sage-dropdown\")\n\n# Import from each skill\nfrom usgs_lidar import fetch_coverage, filter_by_bbox\nfrom sage_bbox_map import show_bbox_map\nfrom sage_dropdown import show_dropdown\n\n# Step 1: Fetch USGS 3DEP coverage catalog\nprint(\"Fetching USGS 3DEP coverage catalog...\")\ncoverage = fetch_coverage()\nprint(f\"Loaded {len(coverage)} USGS 3DEP datasets.\")\n\n# Store in kernel for the reactive dropdown to access\nglobals()[\"coverage\"] = coverage\n\n# Step 2: Show bounding box map with coverage overlay\nshow_bbox_map(\n    bbox_var={\n        \"name\": \"USER_BBOX\",\n        \"description\": \"Bounding box drawn by user on the USGS 3DEP coverage map (EPSG:4326)\",\n    },\n    center=(40, -100),\n    zoom=4,\n    height=\"450px\",\n    header=\"Draw a rectangle on the USGS 3DEP coverage to select an area\",\n    overlay_geojson=coverage,\n    overlay_name=\"USGS 3DEP Coverage\",\n    set_by=\"usgs-lidar via sage-bbox-map\",\n)\n\n# Step 3: Show reactive dropdown that filters datasets by bbox\nshow_dropdown(\n    items_fn=lambda: filter_by_bbox(coverage, globals().get(\"USER_BBOX\"), 20_000_000)\n                     if globals().get(\"USER_BBOX\") else [],\n    observes=\"USER_BBOX\",\n    placeholder=\"Draw a rectangle on the map above to populate this dropdown.\",\n    no_items_message=\"No USGS 3DEP datasets cover the selected area (or all exceed 20 million points). Try a different area.\",\n    label_template=\"{name}  (~{est:,} pts)\",\n    sort_by=\"name\",\n    header=\"Pick a USGS 3DEP dataset that covers the selected area\",\n    description=\"Dataset:\",\n    kernel_vars={\n        \"USER_EPT_URL\": {\n            \"field\": \"url\",\n            \"description\": \"EPT endpoint URL of the user-selected USGS 3DEP dataset\",\n        },\n        \"USER_DATASET_NAME\": {\n            \"field\": \"name\",\n            \"description\": \"Name of the user-selected USGS 3DEP dataset\",\n        },\n    },\n    info_template=(\n        \"Dataset:        {name}\\n\"\n        \"EPT endpoint:   {url}\\n\"\n        \"Total points:   {count:,}\\n\"\n        \"In bbox (est.): {est:,}\"\n    ),\n    set_by=\"usgs-lidar via sage-dropdown\",\n)\n\nprint(\"\\nInteractive widgets rendered above:\")\nprint(\"1. Map: Shows USGS 3DEP coverage nationwide. Draw a rectangle to select your area.\")\nprint(\"2. Dropdown: Auto-populates with datasets under 20M points that intersect your bbox.\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_lidar_pointcloud_sage_/usgs_3dep_coverage_map.py</pre>
#     </div>
#   </details>
# </div>
# <div id="sage-bbox-notice-d8a2c167" data-runtime="1777663987248" style="padding:8px 12px;
#      background:#fff8e1;border-left:3px solid #f4b400;font-size:12px;color:#555;
#      margin:6px 0;border-radius:2px; display:none;">
#     <b>⟳ Interactive widget</b> — re-run this cell to restore map interactivity.
#     Widget callbacks live in the kernel and are lost when the notebook is closed.
# </div>
# <script>
# (function() {
#     var n = document.getElementById("sage-bbox-notice-d8a2c167");
#     if (!n) return;
#     setTimeout(function() {
#         var rt = parseInt(n.getAttribute("data-runtime"), 10);
#         if (Date.now() - rt > 180000) n.style.display = "";
#     }, 100);
#     // Hide "Error displaying widget: model not found" placeholders that
#     // JupyterLab renders after reopen when the widget state isn't saved.
#     // Run multiple passes — JupyterLab renders these asynchronously.
#     var hideBrokenWidgets = function() {
#         var cell = n.closest(".jp-Cell") || n.closest(".jp-OutputArea") || document;
#         // Conservative cleanup — only hide outputs with the literal error text.
#         cell.querySelectorAll(".jp-OutputArea-output").forEach(function(out) {
#             var text = (out.textContent || "").trim();
#             if (/Error displaying widget|model not found/i.test(text) && text.length < 200) {
#                 out.style.display = "none";
#             }
#         });
#     };
#     [200, 600, 1500, 3000, 6000].forEach(function(ms) { setTimeout(hideBrokenWidgets, ms); });
# })();
# </script>
# <div id="sage-dropdown-notice-fd3f462b" data-runtime="1777663987261" style="padding:8px 12px;
#      background:#fff8e1;border-left:3px solid #f4b400;font-size:12px;color:#555;
#      margin:6px 0;border-radius:2px; display:none;">
#     <b>⟳ Interactive widget</b> — re-run this cell to restore dropdown interactivity.
#     Widget callbacks live in the kernel and are lost when the notebook is closed.
# </div>
# <script>
# (function() {
#     var n = document.getElementById("sage-dropdown-notice-fd3f462b");
#     if (!n) return;
#     setTimeout(function() {
#         var rt = parseInt(n.getAttribute("data-runtime"), 10);
#         if (Date.now() - rt > 180000) n.style.display = "";
#     }, 100);
#     // Hide "Error displaying widget: model not found" placeholders that
#     // JupyterLab renders after reopen when the widget state isn't saved.
#     var hideBrokenWidgets = function() {
#         var cell = n.closest(".jp-Cell") || n.closest(".jp-OutputArea") || document;
#         // Hide ONLY outputs whose textContent matches "Error displaying widget" /
#         // "model not found". Conservative — we don't try to identify broken
#         // SVG icons because the same pattern can match valid widget icons
#         // (zoom controls, draw tools, etc.).
#         cell.querySelectorAll(".jp-OutputArea-output").forEach(function(out) {
#             var text = (out.textContent || "").trim();
#             if (/Error displaying widget|model not found/i.test(text) && text.length < 200) {
#                 out.style.display = "none";
#             }
#         });
#     };
#     [200, 600, 1500, 3000, 6000].forEach(function(ms) { setTimeout(hideBrokenWidgets, ms); });
# })();
# </script>
# ## USGS 3DEP Coverage Map
#
# I've created an interactive USGS 3DEP coverage map with a bounding box selection tool and a reactive dropdown. Here's what's available:
#
# **Coverage Catalog** : Loaded 2,252 USGS 3DEP LiDAR datasets nationwide
#
# **Interactive Widgets** :
# 1. **Bounding Box Map** — Displays all USGS 3DEP dataset boundaries as an overlay. Draw a rectangle to select your area of interest.
# 2. **Dataset Dropdown** — Automatically populates with datasets that intersect your bounding box and contain fewer than 20 million points.
#
# **How to use** :
# 1. Draw a rectangle on the map to select your area of interest
# 2. The dropdown will automatically populate with qualifying datasets
# 3. Select a dataset from the dropdown to set `USER_EPT_URL` and `USER_DATASET_NAME` kernel variables
#
# The dropdown format shows each dataset with its estimated point count within your bbox (e.g., "Name  (~1,234,567 pts)"). Once you select a dataset, the EPT endpoint URL and dataset name will be available in kernel variables for downstream processing like downloading point clouds or generating DEMs.

# %%
# %%ask
# Download the USGS 3DEP point cloud for the selected bounding box
# and show point count, elevation range, classification breakdown,
# and a preview image of the point cloud colored by elevation.

# %%
# %%ask
# Generate a 1-meter digital elevation model (DEM) from the
# ground-classified points, and show it as a hillshade overlay on the map.
